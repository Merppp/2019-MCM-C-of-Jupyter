# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("Data/OH_Heroin.xlsx")
data.groupby("COUNTY").sum()['YYYY'].values[0:2]
# Out:
# array([130867, 175193])

# %%
data = pd.read_excel('task3.xlsx')

# %%
date = data['time']
value = data['value']

# %% [markdown]
# ## real_value

# %%
real_value = data['real_value']

# %%
plt.plot(date,real_value)
plt.plot
plt.title('Stepwise regression predicted values',font1)
plt.xlabel('Year',font1)
plt.ylabel('TotalDrugReports',font1)
plt.savefig('real_value.jpg')

# %%
font1 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 11.5,
}

plt.plot(date,value)
plt.title('Stepwise regression prediction after control parameters',font1)
plt.xlabel('Year',font1)
plt.ylabel('TotalDrugReports',font1)
plt.savefig('value.jpg')
