# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
dict = [ky,oh,wv,va,pa]
date = [2010,2011,2012,2013,2014,2015,2016,2017]
ky = [29588,28285,27502,26820,27077,25811,26530,28870]
oh = [70999,71282,85415,93747,101423,109150,115276,119349]
wv = [8668,9310,9429,9062,6926,5345,5405,3672]
va = [41462,28969,32251,47694,32265,27819,33539,36994]
pa = [89981,86793,78577,72096,77318,75351,72376,68751]

# %%
plt.figure(figsize=(10,6))
plt.plot(date,ky)
plt.plot(date,oh)
plt.plot(date,wv)
plt.plot(date,va)
plt.plot(date,pa)
plt.legend(['KY','OH','PA','VA','WV'])

# %%
new_date = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]

# %%
oh_gm = [70999,71282,85415,93747,101423,109150,115276,119349,133570,144220,155730]

# %%
x = [70999,71282,85415,93747,101423,109150,115276,119349,134135.4561,145280,155140];

# %%
plt.plot(new_date,x)
plt.plot(new_date,oh_gm)
plt.legend(['修正','GM'])
