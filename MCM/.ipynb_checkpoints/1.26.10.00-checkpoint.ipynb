# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # HEROIN

# %%
OH_Heroin = pd.read_excel("Data/OH_Heroin.xlsx")

# %%
date = [2010,2011,2012,2013,2014,2015,2016,2017]
HEROIN_LORAIN = [14,21,11,31,42,476,467,353]
HEROIN_LAKE = [193,397,489,811,721,1065,942,568]
HEROIN_OTTAWA = [4,19,12,26,27,23,50,21]

# %% [markdown]
# ## LORAIN和LAKE的关系图

# %%
plt.figure(figsize=(9,5))
plt.plot(date,HEROIN_LORAIN,'r',date,HEROIN_LAKE,'b')
plt.title('Heroin Drug Reports chart')
plt.xlabel('Year')
plt.ylabel('TotalDrugReportsCounty')
plt.legend(['LORAIN','LAKE'],prop={'family':'SimHei','size':14})
plt.savefig('Heroin_LORAIN_LAKE.jpg')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-176-95089fdedc56> in <module>()
#       1 plt.figure(figsize=(9,5))
#       2 plt.plot(date,HEROIN_LORAIN,'r',date,HEROIN_LAKE,'b')
# ----> 3 plt.title('Heroin Drug Reports chart',prop={'family':'SimHei','size':14})
#       4 plt.xlabel('Year')
#       5 plt.ylabel('TotalDrugReportsCounty')
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in title(s, *args, **kwargs)
#    1425
#    1426     """
# -> 1427     return gca().set_title(s, *args, **kwargs)
#    1428
#    1429 ## Axis ##
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in set_title(self, label, fontdict, loc, pad, **kwargs)
#     199         if fontdict is not None:
#     200             title.update(fontdict)
# --> 201         title.update(kwargs)
#     202         return title
#     203
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/text.py in update(self, kwargs)
#     183         sentinel = object()  # bbox can be None, so use another sentinel.
#     184         bbox = kwargs.pop("bbox", sentinel)
# --> 185         super(Text, self).update(kwargs)
#     186         if bbox is not sentinel:
#     187             self.set_bbox(bbox)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/artist.py in update(self, props)
#     886         try:
#     887             ret = [_update_property(self, k, v)
# --> 888                    for k, v in props.items()]
#     889         finally:
#     890             self.eventson = store
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/artist.py in <listcomp>(.0)
#     886         try:
#     887             ret = [_update_property(self, k, v)
# --> 888                    for k, v in props.items()]
#     889         finally:
#     890             self.eventson = store
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#     879                 func = getattr(self, 'set_' + k, None)
#     880                 if not callable(func):
# --> 881                     raise AttributeError('Unknown property %s' % k)
#     882                 return func(v)
#     883
#
# AttributeError: Unknown property prop

# %% [markdown]
# ## LORAIN和LAKE的相关系数（暂时不用管）

# %%
a = np.array(HEROIN_LORAIN)
b = np.array(HEROIN_LAKE)
data = np.vstack((a,b)).T
DF = pd.DataFrame(data,columns=['O_LORAIN','O_LAKE'])
DF.corr()

# %% [markdown]
# ----

# %% [markdown]
# ## LORAIN和OTTAWA的关系图

# %%
plt.figure(figsize=(9,5))
plt.plot(date,HEROIN_LORAIN,'r',date,HEROIN_OTTAWA,'b')
plt.title('Heroin Drug Reports chart')
plt.xlabel('Year')
plt.ylabel('TotalDrugReportsCounty')
plt.legend(['LORAIN','OTTAWA'],prop={'family':'SimHei','size':14})
plt.savefig('Heroin_LORAIN_OTTAWA.jpg')

# %% [markdown]
# ----

# %% [markdown]
# # Synthetic

# %%
Synthetic_LORAIN = [3,0,3,3,6,103,407,579]
Synthetic_LAKE = [25,27,41,46,50,219,996,970]
Synthetic_OTTAWA = [3,0,5,5,3,4,20,27]

# %%
plt.figure(figsize=(9,5))
plt.plot(date,Synthetic_LORAIN,'r',date,Synthetic_LAKE,'b')
plt.title('Synthetic Drug Reports chart')
plt.xlabel('Year')
plt.ylabel('TotalDrugReportsCounty')
plt.legend(['LORAIN','LAKE'],prop={'family':'SimHei','size':14})
plt.savefig('Synthetic_LORAIN_LAKE.jpg')

# %%
plt.figure(figsize=(9,5))
plt.plot(date,Synthetic_LORAIN,'r',date,Synthetic_OTTAWA,'b')
plt.title('Synthetic Drug Reports chart')
plt.xlabel('Year')
plt.ylabel('TotalDrugReportsCounty')
plt.legend(['LORAIN','OTTAWA'],prop={'family':'SimHei','size':14})
plt.savefig('Synthetic_LORAIN_OTTAWA.jpg')
